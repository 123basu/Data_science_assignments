# %% [markdown]
# Exercise 1: Prime Numbers
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
def isprime (num):
    if num <= 1:
        return "It is not a Prime number"
    for i in range(2, num):
        if num % i == 0:
            return "It is not a Prime number"
    return "It is a Prime number"

num = int(input("Enter the number"))
print(isprime(num))
# Out:
# Enter the number 4653
# It is not a Prime number

# %% [markdown]
# Exercise 2: Product of Random Numbers
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random

# %%
num1 = random.randint(1, 100)
num2 = random.randint(1, 100)

user_product = int(input(f"Enter the product of number {num1} and {num2} : "))
if user_product == (num1*num2):
    print("You answered it right!!")
    print(f"The product of two numbers is {user_product}")
else:
    print("Wrong!, better luck next time ")
    print(f"The correct answer is {(num1*num2)}")
# Out:
# Enter the product of number 53 and 52 :  234345
# Wrong!, better luck next time
# The correct answer is 2756

# %% [markdown]
# Exercise 3: Squares of Even/Odd Numbers
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and       document your choice in the code.

# %%
# i choose even numbers to print their squred values 

for i in range (100, 201):
    if i % 2 == 0:
        print(f" squre of even number {i} is {i*i}")
# Out:
#  squre of even number 100 is 10000
#  squre of even number 102 is 10404
#  squre of even number 104 is 10816
#  squre of even number 106 is 11236
#  squre of even number 108 is 11664
#  squre of even number 110 is 12100
#  squre of even number 112 is 12544
#  squre of even number 114 is 12996
#  squre of even number 116 is 13456
#  squre of even number 118 is 13924
#  squre of even number 120 is 14400
#  squre of even number 122 is 14884
#  squre of even number 124 is 15376
#  squre of even number 126 is 15876
#  squre of even number 128 is 16384
#  squre of even number 130 is 16900
#  squre of even number 132 is 17424
#  squre of even number 134 is 17956
#  squre of even number 136 is 18496
#  squre of even number 138 is 19044
#  squre of even number 140 is 19600
#  squre of even number 142 is 20164
#  squre of even number 144 is 20736
#  squre of even number 146 is 21316
#  squre of even number 148 is 21904
#  squre of even number 150 is 22500
#  squre of even number 152 is 23104
#  squre of even number 154 is 23716
#  squre of even number 156 is 24336
#  squre of even number 158 is 24964
#  squre of even number 160 is 25600
#  squre of even number 162 is 26244
#  squre of even number 164 is 26896
#  squre of even number 166 is 27556
#  squre of even number 168 is 28224
#  squre of even number 170 is 28900
#  squre of even number 172 is 29584
#  squre of even number 174 is 30276
#  squre of even number 176 is 30976
#  squre of even number 178 is 31684
#  squre of even number 180 is 32400
#  squre of even number 182 is 33124
#  squre of even number 184 is 33856
#  squre of even number 186 is 34596
#  squre of even number 188 is 35344
#  squre of even number 190 is 36100
#  squre of even number 192 is 36864
#  squre of even number 194 is 37636
#  squre of even number 196 is 38416
#  squre of even number 198 is 39204
#  squre of even number 200 is 40000

# %% [markdown]
# Exercise 4:
# ✅ Problem Statement (Question): Hospital Billing System
# A hospital charges its patients based on the following:
# •	Room charges per day: ₹2,000
# •	Doctor consultation fee (flat): ₹1,500
# •	Lab test charges: Based on the number of tests taken. Each test costs ₹300
# •	Medicine charges: Total cost of medicines provided
# •	Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
# Write a Python program to calculate the final bill for a patient who:
# •	Stayed for 4 days
# •	Had 3 lab tests
# •	Had medicine charges of ₹2,400

# %%
class Billing:
    def __init__(self, days_in_room, lab_tests, medician):
        self.total_Room_charges = 2000*days_in_room
        self.Doctor_consultation_fee = 1500
        self.Lab_test_charges = 300*num_lab_test
        self.medician_charges = medician
        self.discount = 10

    def calculate_bill (self):
        total_amount = self.total_Room_charges +  self.Doctor_consultation_fee + self.Lab_test_charges + self.medician_charges 
        if total_amount > 10000:
            discount_amount = (self.discount/100)*total_amount
            after_discount = total_amount - discount_amount
            return total_amount, after_discount
        else:
            return total_amount, 0
        


days_in_room =4
num_lab_test =  3
medician = 2400
obj = Billing(days_in_room, num_lab_test, medician)

total_amount, final_amount = obj.calculate_bill()

print(f"Your total amount is :{total_amount}")
if total_amount > 10000:
    print(f"After discount :{final_amount}")
# Out:
# Your total amount is :12800
# After discount :11520.0
